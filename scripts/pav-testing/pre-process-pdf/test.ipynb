# %% [markdown]
# # Testing Document Loaders

# %%
import pprint

DATA_PATH = "C:/Users/patri/Documents/Learning Sources/github/locallm/data/pdfs/pav"

# %% [markdown]
# ### PyPDFLoader

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.document_loaders.parsers import LLMImageBlobParser
from langchain_ollama import ChatOllama

# %%
loader_pypdf = PyPDFLoader(
    file_path=DATA_PATH + "/extract.pdf",
    mode = "page",
    extract_images=True,
    images_parser=LLMImageBlobParser(
        model=ChatOllama(
            model="gemma3:4b",
            temperature=1,
            num_predict=1024
        )
    ),
    images_inner_format="markdown-img",
    extraction_mode="layout"
)

docs_pypdf = loader_pypdf.load()

print(f"Number of docs: {len(docs_pypdf)}")
pprint.pp(docs_pypdf[0].metadata)
pprint.pp(docs_pypdf[0].page_content)
# Out:
# Number of docs: 8
# {'producer': 'iLovePDF',
#  'creator': 'PyPDF',
#  'creationdate': '',
#  'moddate': '2025-07-02T11:13:36+00:00',
#  'source': 'C:/Users/patri/Documents/Learning '
#            'Sources/github/locallm/data/pdfs/pav/extract.pdf',
#  'total_pages': 8,
#  'page': 0,
#  'page_label': '1'}
# ('Kanton Zürich, Volkswirtschaftsdirektion\n'
#  '                                                                     Amt für '
#  'Mobilität\n'
#  '                                                                     AP '
#  'Winterthur und Umgebung, 5. Generation\n'
#  '                                                                     Teil 1: '
#  'Bericht\n'
#  '                                                                     37/228\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '4         Situations- und Trendanalyse\n'
#  '\n'
#  '\n'
#  'Hinweis Mobilitätsdaten und COVID-19-Pandemie\n'
#  'Die Situations-   und Trendanalyse im Bereich Mobilität und Verkehr enthält '
#  'verschiedene\n'
#  'Auswertungen, welche Daten aus den vergangenen Jahren abbilden. Dabei ist zu '
#  'berück-\n'
#  'sichtigen, dass die Pandemie und die entsprechenden gesundheitspolitischen '
#  'Massnahmen\n'
#  '(wie zeitweise geltende Homeoffice       -Pflicht, Schliessung öffentlicher '
#  'Einrichtungen) teilweise\n'
#  'einen starken Einfluss auf die Mobilität der Bevölkerung hatten. Dies '
#  'widerspiegelt sich vor\n'
#  'allem in den Daten aus den Jahren 2020 und 2021 und betrifft '
#  'folglich              auch die Ergebnisse\n'
#  'des 2021 durchgeführten Mikrozensus Mobilität und Verkehr (MZMV). Die '
#  'betreffenden Da-\n'
#  'ten sind daher spezifisch zu interpretieren. Vor allem gilt dies beim '
#  'Vergleich mit denselben\n'
#  'Daten früherer Jahre.\n'
#  '\n'
#  ' Das Wichtigste in Kürze\n'
#  '\n'
#  ' Stärken\n'
#  ' •  Räumliche Gliederung: Es besteht eine klare räumliche Gliederung in '
#  'Kernstadt, ur-\n'
#  '    bane Landschaften und ländliche Umgebung. Neben der Kernstadt Winterthur '
#  'stellen\n'
#  '    die Stadt Illnau-Effretikon, aber auch Gemeinden wie Seuzach, Elgg und '
#  'Turbenthal\n'
#  '    regionale und lokale Zentren dar. Sowohl die infrastrukturelle als auch '
#  'die funktionale\n'
#  '    Vernetzung zwischen Winterthur und den Nachbargemeinden ist gross.\n'
#  ' •  Bevölkerung und Arbeitsplätze: Die Bevölkerung konzentriert sich auf den '
#  'urbanen\n'
#  '    Raum. Die Arbeitsplätze konzentrieren sich stark auf die Stadt '
#  'Winterthur, lokales Ge-\n'
#  '    werbe ist aber in allen Gemeinden der Region vorhanden.\n'
#  ' •  Siedlung:     Nutzungsverdichtungen werden an gut erschlossenen Lagen '
#  'umgesetzt.\n'
#  '    Die Stadt Winterthur weist ein grosses regionales Kultur-, Einkaufs-, '
#  'Freizeit- und Bil-\n'
#  '    dungsangebot auf. Die grössten Flächenpotenziale für Wohnen und Arbeiten '
#  'liegen in\n'
#  '    der Kernstadt und den urbanen Wohnlandschaften in der überbauten '
#  'Bauzone. Die\n'
#  '    Gemeinden setzen auf eine Erhöhung der Bauzonenausnützung.\n'
#  ' •  Landschaftsräume:         Es bestehen im ganzen          '
#  'AP-Perimeter      wertvolle Landschafts-\n'
#  '    räume mit hoher Bedeutung für Ökologie, Landwirtschaft und Naherholung. '
#  'Diese wer-\n'
#  '    den mit attraktiven städtischen Freiräumen innerhalb der Siedlung '
#  'ergänzt. Mit einem\n'
#  '    Waldanteil von rund 36% ist die Region Winterthur und Umgebung der '
#  'waldreichste\n'
#  '    Forstkreis im Kanton Zürich.\n'
#  ' •  Luft- und Lärmbelastung: Die Luftbelastung konnte durch den technischen '
#  'Fortschritt\n'
#  '    weiter reduziert werden. Lärmschutzmassnahmen werden wo möglich '
#  'realisiert.\n'
#  ' •  Klimaschutz und -anpassung: Hitzeminderungsmassnahmen werden im Hinblick '
#  'auf\n'
#  '    die Klimaveränderung vermehrt von Wichtigkeit sein. Aktuell ist '
#  'insbesondere in den\n'
#  '    dicht bebauten Siedlungsräumen eine Überwärmung festzustellen.\n'
#  ' •  Gesamtverkehr: Der ÖV-Anteil in der Region für Fahrten nach Zürich liegt '
#  'bei 63%.\n'
#  ' •  ÖV: Es existiert ein attraktives S-Bahn-Angebot mit zahlreichen '
#  'Bahnhöfen in der Stadt\n'
#  '    Winterthur und der Region sowie mit Fernverkehrsverbindungen ab '
#  'Winterthur. Aus-\n'
#  '    serhalb der Stadt verläuft der Busbetrieb weitgehend störungsfrei.')

# %% [markdown]
# Performance: Quite fast, but the loader cannot differ between an actual linebreaks and sentences that continue on the next line...
#
# Moreover, the coloured textboxes are not directly interpreted as text, and again, new and continuing lines are not spotted (but may identifiable by the "unordered-list-dot").
#
# Somehow images are not captured at all??

# %% [markdown]
# ### PyMuPDF

# %%
from langchain_community.document_loaders import PyMuPDFLoader

# %%
loader_pymu = PyMuPDFLoader(
    file_path=DATA_PATH + "/extract.pdf",
    mode = "page",
    extract_tables="markdown",
    extract_images=True,
    images_parser=LLMImageBlobParser(
        model=ChatOllama(
            model="gemma3:4b",
            temperature=1,
            num_predict=1024
        )
    ),
    images_inner_format="markdown-img"
)

docs_pymu = loader_pymu.load()

print(f"Number of docs: {len(docs_pymu)}")
pprint.pp(docs_pymu[0].metadata)
pprint.pp(docs_pymu[0].page_content)
# Out:
# Number of docs: 8
# {'producer': 'iLovePDF',
#  'creator': '',
#  'creationdate': '',
#  'source': 'C:/Users/patri/Documents/Learning '
#            'Sources/github/locallm/data/pdfs/pav/extract.pdf',
#  'file_path': 'C:/Users/patri/Documents/Learning '
#               'Sources/github/locallm/data/pdfs/pav/extract.pdf',
#  'total_pages': 8,
#  'format': 'PDF 1.7',
#  'title': '',
#  'author': '',
#  'subject': '',
#  'keywords': '',
#  'moddate': '2025-07-02T11:13:36+00:00',
#  'trapped': '',
#  'modDate': 'D:20250702111336Z',
#  'creationDate': '',
#  'page': 0}
# ('Kanton Zürich, Volkswirtschaftsdirektion \n'
#  'Amt für Mobilität \n'
#  'AP Winterthur und Umgebung, 5. Generation \n'
#  'Teil 1: Bericht \n'
#  '37/228 \n'
#  ' \n'
#  ' \n'
#  '4 \n'
#  'Situations- und Trendanalyse  \n'
#  'Hinweis Mobilitätsdaten und COVID-19-Pandemie \n'
#  'Die Situations- und Trendanalyse im Bereich Mobilität und Verkehr enthält '
#  'verschiedene \n'
#  'Auswertungen, welche Daten aus den vergangenen Jahren abbilden. Dabei ist zu '
#  'berück-\n'
#  'sichtigen, dass die Pandemie und die entsprechenden gesundheitspolitischen '
#  'Massnahmen \n'
#  '(wie zeitweise geltende Homeoffice-Pflicht, Schliessung öffentlicher '
#  'Einrichtungen) teilweise \n'
#  'einen starken Einfluss auf die Mobilität der Bevölkerung hatten. Dies '
#  'widerspiegelt sich vor \n'
#  'allem in den Daten aus den Jahren 2020 und 2021 und betrifft folglich auch '
#  'die Ergebnisse \n'
#  'des 2021 durchgeführten Mikrozensus Mobilität und Verkehr (MZMV). Die '
#  'betreffenden Da-\n'
#  'ten sind daher spezifisch zu interpretieren. Vor allem gilt dies beim '
#  'Vergleich mit denselben \n'
#  'Daten früherer Jahre. \n'
#  'Das Wichtigste in Kürze \n'
#  'Stärken \n'
#  '• Räumliche Gliederung: Es besteht eine klare räumliche Gliederung in '
#  'Kernstadt, ur-\n'
#  'bane Landschaften und ländliche Umgebung. Neben der Kernstadt Winterthur '
#  'stellen \n'
#  'die Stadt Illnau-Effretikon, aber auch Gemeinden wie Seuzach, Elgg und '
#  'Turbenthal \n'
#  'regionale und lokale Zentren dar. Sowohl die infrastrukturelle als auch die '
#  'funktionale \n'
#  'Vernetzung zwischen Winterthur und den Nachbargemeinden ist gross.  \n'
#  '• Bevölkerung und Arbeitsplätze: Die Bevölkerung konzentriert sich auf den '
#  'urbanen \n'
#  'Raum. Die Arbeitsplätze konzentrieren sich stark auf die Stadt Winterthur, '
#  'lokales Ge-\n'
#  'werbe ist aber in allen Gemeinden der Region vorhanden. \n'
#  '• Siedlung: Nutzungsverdichtungen werden an gut erschlossenen Lagen '
#  'umgesetzt. \n'
#  'Die Stadt Winterthur weist ein grosses regionales Kultur-, Einkaufs-, '
#  'Freizeit- und Bil-\n'
#  'dungsangebot auf. Die grössten Flächenpotenziale für Wohnen und Arbeiten '
#  'liegen in \n'
#  'der Kernstadt und den urbanen Wohnlandschaften in der überbauten Bauzone. '
#  'Die \n'
#  'Gemeinden setzen auf eine Erhöhung der Bauzonenausnützung.  \n'
#  '• Landschaftsräume: Es bestehen im ganzen AP-Perimeter wertvolle '
#  'Landschafts-\n'
#  'räume mit hoher Bedeutung für Ökologie, Landwirtschaft und Naherholung. '
#  'Diese wer-\n'
#  'den mit attraktiven städtischen Freiräumen innerhalb der Siedlung ergänzt. '
#  'Mit einem \n'
#  'Waldanteil von rund 36% ist die Region Winterthur und Umgebung der '
#  'waldreichste \n'
#  'Forstkreis im Kanton Zürich.  \n'
#  '• Luft- und Lärmbelastung: Die Luftbelastung konnte durch den technischen '
#  'Fortschritt \n'
#  'weiter reduziert werden. Lärmschutzmassnahmen werden wo möglich '
#  'realisiert. \n'
#  '• Klimaschutz und -anpassung: Hitzeminderungsmassnahmen werden im Hinblick '
#  'auf \n'
#  'die Klimaveränderung vermehrt von Wichtigkeit sein. Aktuell ist insbesondere '
#  'in den \n'
#  'dicht bebauten Siedlungsräumen eine Überwärmung festzustellen. \n'
#  '• Gesamtverkehr: Der ÖV-Anteil in der Region für Fahrten nach Zürich liegt '
#  'bei 63%.  \n'
#  '• ÖV: Es existiert ein attraktives S-Bahn-Angebot mit zahlreichen Bahnhöfen '
#  'in der Stadt \n'
#  'Winterthur und der Region sowie mit Fernverkehrsverbindungen ab Winterthur. '
#  'Aus-\n'
#  'serhalb der Stadt verläuft der Busbetrieb weitgehend störungsfrei. \n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '|Col1|Das Wichtigste in Kürze|Col3|\n'
#  '|---|---|---|\n'
#  '||Stärken||\n'
#  '||• Räumliche Gliederung: Es besteht eine klare räumliche Gliederung in '
#  'Kernstadt, ur-||\n'
#  '||bane Landschaften und ländliche Umgebung. Neben der Kernstadt Winterthur '
#  'stellen|bane Landschaften und ländliche Umgebung. Neben der Kernstadt '
#  'Winterthur stellen|\n'
#  '||die Stadt Illnau-Effretikon, aber auch Gemeinden wie Seuzach, Elgg und '
#  'Turbenthal|die Stadt Illnau-Effretikon, aber auch Gemeinden wie Seuzach, '
#  'Elgg und Turbenthal|\n'
#  '||regionale und lokale Zentren dar. Sowohl die infrastrukturelle als auch '
#  'die funktionale|regionale und lokale Zentren dar. Sowohl die '
#  'infrastrukturelle als auch die funktionale|\n'
#  '||Vernetzung zwischen Winterthur und den Nachbargemeinden ist '
#  'gross.|Vernetzung zwischen Winterthur und den Nachbargemeinden ist gross.|\n'
#  '||• Bevölkerung und Arbeitsplätze: Die Bevölkerung konzentriert sich auf den '
#  'urbanen||\n'
#  '||Raum. Die Arbeitsplätze konzentrieren sich stark auf die Stadt Winterthur, '
#  'lokales Ge-|Raum. Die Arbeitsplätze konzentrieren sich stark auf die Stadt '
#  'Winterthur, lokales Ge-|\n'
#  '||werbe ist aber in allen Gemeinden der Region vorhanden.|werbe ist aber in '
#  'allen Gemeinden der Region vorhanden.|\n'
#  '||• Siedlung: Nutzungsverdichtungen werden an gut erschlossenen Lagen '
#  'umgesetzt.||\n'
#  '||Die Stadt Winterthur weist ein grosses regionales Kultur-, Einkaufs-, '
#  'Freizeit- und Bil-|Die Stadt Winterthur weist ein grosses regionales '
#  'Kultur-, Einkaufs-, Freizeit- und Bil-|\n'
#  '||dungsangebot auf. Die grössten Flächenpotenziale für Wohnen und Arbeiten '
#  'liegen in|dungsangebot auf. Die grössten Flächenpotenziale für Wohnen und '
#  'Arbeiten liegen in|\n'
#  '||der Kernstadt und den urbanen Wohnlandschaften in der überbauten Bauzone. '
#  'Die|der Kernstadt und den urbanen Wohnlandschaften in der überbauten '
#  'Bauzone. Die|\n'
#  '||Gemeinden setzen auf eine Erhöhung der Bauzonenausnützung.|Gemeinden '
#  'setzen auf eine Erhöhung der Bauzonenausnützung.|\n'
#  '||• Landschaftsräume: Es bestehen im ganzen AP-Perimeter wertvolle '
#  'Landschafts-||\n'
#  '||räume mit hoher Bedeutung für Ökologie, Landwirtschaft und Naherholung. '
#  'Diese wer-|räume mit hoher Bedeutung für Ökologie, Landwirtschaft und '
#  'Naherholung. Diese wer-|\n'
#  '||den mit attraktiven städtischen Freiräumen innerhalb der Siedlung ergänzt. '
#  'Mit einem|den mit attraktiven städtischen Freiräumen innerhalb der Siedlung '
#  'ergänzt. Mit einem|\n'
#  '||Waldanteil von rund 36% ist die Region Winterthur und Umgebung der '
#  'waldreichste|Waldanteil von rund 36% ist die Region Winterthur und Umgebung '
#  'der waldreichste|\n'
#  '||Forstkreis im Kanton Zürich.|Forstkreis im Kanton Zürich.|\n'
#  '||• Luft- und Lärmbelastung: Die Luftbelastung konnte durch den technischen '
#  'Fortschritt||\n'
#  '||weiter reduziert werden. Lärmschutzmassnahmen werden wo möglich '
#  'realisiert.|weiter reduziert werden. Lärmschutzmassnahmen werden wo möglich '
#  'realisiert.|\n'
#  '||• Klimaschutz und -anpassung: Hitzeminderungsmassnahmen werden im Hinblick '
#  'auf||\n'
#  '||die Klimaveränderung vermehrt von Wichtigkeit sein. Aktuell ist '
#  'insbesondere in den|die Klimaveränderung vermehrt von Wichtigkeit sein. '
#  'Aktuell ist insbesondere in den|\n'
#  '||dicht bebauten Siedlungsräumen eine Überwärmung festzustellen.|dicht '
#  'bebauten Siedlungsräumen eine Überwärmung festzustellen.|\n'
#  '||• Gesamtverkehr: Der ÖV-Anteil in der Region für Fahrten nach Zürich liegt '
#  'bei 63%.||\n'
#  '||• ÖV: Es existiert ein attraktives S-Bahn-Angebot mit zahlreichen '
#  'Bahnhöfen in der Stadt||\n'
#  '||Winterthur und der Region sowie mit Fernverkehrsverbindungen ab '
#  'Winterthur. Aus-|Winterthur und der Region sowie mit '
#  'Fernverkehrsverbindungen ab Winterthur. Aus-|\n'
#  '||serhalb der Stadt verläuft der Busbetrieb weitgehend störungsfrei.|serhalb '
#  'der Stadt verläuft der Busbetrieb weitgehend störungsfrei.|')

# %% [markdown]
# Performance: Significantly slower than PyPDFLoader; the loader cannot differ between an actual linebreaks and sentences that continue on the next line...
#
# Moreover, the coloured textboxes are interpreted as tables, and again, new and continuing lines are not spotted (but may identifiable by the "unordered-list-dot").
#
# Somehow images are not captured at all??

# %% [markdown]
# ### PyMuPDF4LLM

# %%
from langchain_pymupdf4llm import PyMuPDF4LLMLoader

# %%
# using langchain integration first without image extraction
loader_4llm = PyMuPDF4LLMLoader(
    file_path=DATA_PATH + "/extract.pdf",
    mode = "page"
)

docs_4llm = loader_4llm.load()

print(f"Number of docs: {len(docs_4llm)}")
pprint.pp(docs_4llm[0].metadata)
pprint.pp(docs_4llm[0].page_content)
# Out:
# Number of docs: 1
# {'producer': 'iLovePDF',
#  'creator': '',
#  'creationdate': '',
#  'source': 'C:/Users/patri/Documents/Learning '
#            'Sources/github/locallm/data/pdfs/pav/extract.pdf',
#  'file_path': 'C:/Users/patri/Documents/Learning '
#               'Sources/github/locallm/data/pdfs/pav/extract.pdf',
#  'total_pages': 8,
#  'format': 'PDF 1.7',
#  'title': '',
#  'author': '',
#  'subject': '',
#  'keywords': '',
#  'moddate': '2025-07-02T11:13:36+00:00',
#  'trapped': '',
#  'modDate': 'D:20250702111336Z',
#  'creationDate': '',
#  'page': 0}
# ('Kanton Zürich, Volkswirtschaftsdirektion\n'
#  '\n'
#  'Amt für Mobilität\n'
#  '\n'
#  'AP Winterthur und Umgebung, 5. Generation\n'
#  'Teil 1: Bericht\n'
#  '\n'
#  '37/228\n'
#  '# 4 Situations- und Trendanalyse \n'
#  '\n'
#  'Hinweis Mobilitätsdaten und COVID-19-Pandemie\n'
#  '\n'
#  'Die Situations- und Trendanalyse im Bereich Mobilität und Verkehr enthält '
#  'verschiedene\n'
#  'Auswertungen, welche Daten aus den vergangenen Jahren abbilden. Dabei ist zu '
#  'berücksichtigen, dass die Pandemie und die entsprechenden '
#  'gesundheitspolitischen Massnahmen\n'
#  '(wie zeitweise geltende Homeoffice-Pflicht, Schliessung öffentlicher '
#  'Einrichtungen) teilweise\n'
#  'einen starken Einfluss auf die Mobilität der Bevölkerung hatten. Dies '
#  'widerspiegelt sich vor\n'
#  'allem in den Daten aus den Jahren 2020 und 2021 und betrifft folglich auch '
#  'die Ergebnisse\n'
#  'des 2021 durchgeführten Mikrozensus Mobilität und Verkehr (MZMV). Die '
#  'betreffenden Daten sind daher spezifisch zu interpretieren. Vor allem gilt '
#  'dies beim Vergleich mit denselben\n'
#  'Daten früherer Jahre.\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n')

# %% [markdown]
# Somehow, PyMuPDF4LLM cannot extract the tables? And there is no argument to "extract_tables" such as in the normal PyMuPDF version...

# %%
# trying image extraction with Ollama
loader_multi = PyMuPDF4LLMLoader(
    file_path=DATA_PATH + "/extract.pdf",
    mode = "single",
    extract_images=True,
    images_parser=LLMImageBlobParser(
        model=ChatOllama(
            model="gemma3:4b",
            temperature=1,
            num_predict=1024
        )
    )
)

docs_multi = loader_multi.load()

print(f"Number of docs: {len(docs_multi)}")
pprint.pp(docs_multi[0].metadata)
pprint.pp(docs_multi[0].page_content)
# Out:
# Number of docs: 1
# {'producer': 'iLovePDF',
#  'creator': '',
#  'creationdate': '',
#  'source': 'C:/Users/patri/Documents/Learning '
#            'Sources/github/locallm/data/pdfs/pav/extract.pdf',
#  'file_path': 'C:/Users/patri/Documents/Learning '
#               'Sources/github/locallm/data/pdfs/pav/extract.pdf',
#  'total_pages': 8,
#  'format': 'PDF 1.7',
#  'title': '',
#  'author': '',
#  'subject': '',
#  'keywords': '',
#  'moddate': '2025-07-02T11:13:36+00:00',
#  'trapped': '',
#  'modDate': 'D:20250702111336Z',
#  'creationDate': ''}
# ('Kanton Zürich, Volkswirtschaftsdirektion\n'
#  '\n'
#  'Amt für Mobilität\n'
#  '\n'
#  'AP Winterthur und Umgebung, 5. Generation\n'
#  'Teil 1: Bericht\n'
#  '\n'
#  '37/228\n'
#  '# 4 Situations- und Trendanalyse \n'
#  '\n'
#  'Hinweis Mobilitätsdaten und COVID-19-Pandemie\n'
#  '\n'
#  'Die Situations- und Trendanalyse im Bereich Mobilität und Verkehr enthält '
#  'verschiedene\n'
#  'Auswertungen, welche Daten aus den vergangenen Jahren abbilden. Dabei ist zu '
#  'berücksichtigen, dass die Pandemie und die entsprechenden '
#  'gesundheitspolitischen Massnahmen\n'
#  '(wie zeitweise geltende Homeoffice-Pflicht, Schliessung öffentlicher '
#  'Einrichtungen) teilweise\n'
#  'einen starken Einfluss auf die Mobilität der Bevölkerung hatten. Dies '
#  'widerspiegelt sich vor\n'
#  'allem in den Daten aus den Jahren 2020 und 2021 und betrifft folglich auch '
#  'die Ergebnisse\n'
#  'des 2021 durchgeführten Mikrozensus Mobilität und Verkehr (MZMV). Die '
#  'betreffenden Daten sind daher spezifisch zu interpretieren. Vor allem gilt '
#  'dies beim Vergleich mit denselben\n'
#  'Daten früherer Jahre.\n'
#  '\n'
#  '\n'
#  '![**Summary:**\n'
#  '\n'
#  'The image depicts urban areas of Winterthur, including transportation hubs, '
#  'housing, and commercial spaces. Key elements include the S-Bahn network, the '
#  'Winterthur train station, and a focus on urban development and environmental '
#  'considerations.\n'
#  '\n'
#  '**Extracted Text:**\n'
#  '\n'
#  '*   ÖV: Existent sind S-Bahn-Angebot mit zahlreichen Bahnhöfen in der Stadt '
#  'Winterthur und der Region sowie mit Fernverkehrsverbindungen auf '
#  'Winterthur.\n'
#  '*   Ausserhalb der Stadt Winterthur sind die Busbetriebe störungsfrei.\n'
#  '*   Lärmschutzmassnahmen werden im Hinblick auf die Klimaveränderung '
#  'vermehrt von Wichtigkeit.\n'
#  '*   Aktuell ist die Lärmschutzmassnahme für eine Überwachung gesteckt.](#)\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '-----\n'
#  '\n'
#  'Kanton Zürich, Volkswirtschaftsdirektion\n'
#  '\n'
#  'Amt für Mobilität\n'
#  '\n'
#  'AP Winterthur und Umgebung, 5. Generation\n'
#  'Teil 1: Bericht\n'
#  '\n'
#  '38/228\n'
#  '\n'
#  '\n'
#  '![**Summary:**\n'
#  '\n'
#  'The image depicts a map of the city of Winterthur, Switzerland, highlighting '
#  'various transportation options including car, public transport (especially '
#  'trams), and cycling. The map is divided into zones and indicates key areas '
#  "like workplaces and residential areas. It showcases the city's multi-modal "
#  'approach to mobility.\n'
#  '\n'
#  '**Extracted Text:**\n'
#  '\n'
#  '*   MIV-Anlage\n'
#  '*   Raumliche Verordnung\n'
#  '*   Stadtebene\n'
#  '*   Multi-Modalität\n'
#  '*   Zonen\n'
#  '*   Arbeitsplätze\n'
#  '*   Einwohner\n'
#  '*   Verkehr\n'
#  '*   Länder\n'
#  '*   Stadt Winterthur\n'
#  '*   Trampo-Räder\n'
#  '*   Überverkehrsfläche\n'
#  '*   Ungeordneter Straßenweise\n'
#  '*   Die Fahrzeugs\n'
#  '*   Die Stadt Winterthur\n'
#  '*   Eine Stadt\n'
#  '*   Einwohner](#)\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '-----\n'
#  '\n'
#  'Kanton Zürich, Volkswirtschaftsdirektion\n'
#  '\n'
#  'Amt für Mobilität\n'
#  '\n'
#  'AP Winterthur und Umgebung, 5. Generation\n'
#  'Teil 1: Bericht\n'
#  '\n'
#  '39/228\n'
#  '\n'
#  '\n'
#  '![**Summary:**\n'
#  '\n'
#  'The image depicts a railway scene with a focus on passenger and freight '
#  'transportation, including train tracks, signal systems, and information '
#  'about stations like Erfurt and Winterthur. It highlights the integrated '
#  'mobility and safety measures related to rail transport.\n'
#  '\n'
#  '**Extracted Text:**\n'
#  '\n'
#  '*   Hauptverkehrsstraßen\n'
#  '*   DeB+R-Anlagen\n'
#  '*   Weisen teilweise mangelhafte Ausstattungen\n'
#  '*   Erfurt\n'
#  '*   Winterthur\n'
#  '*   Grü̈̈̈̈̈̈̈̈̈̈̈̈̈̈̈̈̈̈̈̈̈̈̈̈̈̈̈̈̈̈](#)\n'
#  '\n'
#  '## 4.1 Siedlung\n'
#  '\n'
#  '4.1.1 Räumliche Gliederung\n'
#  '\n'
#  'Die Agglomeration Winterthur und Umgebung ist eingebettet in den '
#  'Metropolraum Zürich.\n'
#  'Winterthur ist die zweitgrösste Stadt im Kanton Zürich und liegt bezüglich '
#  'Dichte des urbanen\n'
#  'Gebiets an zweiter Stelle im Kanton. Die Region hat eine hohe Attraktivität '
#  'und Nutzungsintensität mit steigenden Bevölkerungs- und Arbeitsplatzzahlen '
#  'sowie Bodenpreisen. Im Metropolitanraum Zürich hat sich Winterthur als ein '
#  'eigenständiges Zentrum profiliert und wird\n'
#  'zunehmend attraktiver für Bevölkerungsgruppen mit einem urbanen Lebensstil. '
#  'Zwei der elf\n'
#  'Zentrumsgebiete von kantonaler Bedeutung liegen in der Stadt Winterthur: die '
#  'Gebiete Winterthur-Zentrum und Oberwinterthur/Grüze. Neben den beiden '
#  'Zentrumsgebieten von kantonaler Bedeutung gibt es in den Städten Winterthur '
#  'und Illnau-Effretikon, in Elgg, Seuzach\n'
#  'und Turbenthal verschiedene regionale und lokale Zentren.\n'
#  '\n'
#  'Der AP-Perimeter ist von einer Hügellandschaft geprägt und die hohe Qualität '
#  'der Natur und\n'
#  'Landschaft ist ein wesentliches Merkmal der Region. Kennzeichnend für die '
#  'Region ist, dass\n'
#  'die einzelnen Siedlungen auch im ersten Agglomerationsgürtel um die Stadt '
#  'Winterthur kaum\n'
#  'zusammengewachsen sind. In der Kernstadt Winterthur sind die sieben Hügel '
#  'strukturbildend.\n'
#  '\n'
#  '\n'
#  '-----\n'
#  '\n'
#  'Kanton Zürich, Volkswirtschaftsdirektion\n'
#  '\n'
#  'Amt für Mobilität\n'
#  '\n'
#  'AP Winterthur und Umgebung, 5. Generation\n'
#  'Teil 1: Bericht\n'
#  '\n'
#  '40/228\n'
#  '\n'
#  'Die «Stadtlandschaft» gemäss kantonalem Raumordnungskonzept (ROK) ist auf '
#  'die beiden\n'
#  'Städte Winterthur und Illnau-Effretikon begrenzt. Seuzach, Elsau und '
#  'Wiesendangen grenzen als «urbane Wohnlandschaften» unmittelbar an die '
#  'Kernstadt Winterthur an. Alle übrigen\n'
#  'Gemeinden im AP-Perimeter gehören zum nicht urbanen Raum und sind der '
#  '«Landschaft\n'
#  'unter Druck», der «Kulturlandschaft» oder der «Naturlandschaft» gemäss ROK '
#  'zugeordnet.\n'
#  'Der Einbezug aller Gemeinden der Region Winterthur und Umgebung in die '
#  'Agglomerationsplanung dient der Abstimmung der städtischen und '
#  'landschaftlichen Massnahmen sowie\n'
#  'der einzelnen Gemeindeinteressen und -anliegen.\n'
#  '\n'
#  '![**Summary:**\n'
#  '\n'
#  'Karte des urbanen Wohnungsbaus (RÖK) mit dem Regionalen Zentrumsgebiet (RÖK) '
#  'und der S-Bahn-Haltestelle.\n'
#  '\n'
#  '**Extracted Text:**\n'
#  '\n'
#  'Karte des urbanen Wohnungsbaus (RÖK)\n'
#  'mit dem Regionalen Zentrumsgebiet (RÖK)\n'
#  'und der S-Bahn-Haltestelle.\n'
#  '0\n'
#  '4.5\n'
#  '8.5\n'
#  '13.5](#)\n'
#  '\n'
#  '**Abbildung 4** **Funktionalräumliche Gliederung 2023**\n'
#  '\n'
#  '![**Summary:**\n'
#  '\n'
#  'The image shows a map or diagram depicting a cityscape, likely a transit map '
#  'or urban planning scheme.\n'
#  '\n'
#  '**Extracted Text:**\n'
#  '\n'
#  'S-Bahn\n'
#  'Urbane\n'
#  'Zentrum\n'
#  'Stadtbahn\n'
#  'Haltestelle\n'
#  'KRP\n'
#  'ROK](#)\n'
#  '\n'
#  'Quellen: KRP ZH, RRP und ROK: ARE ZH (2023); Urbaner Entwicklungsraum sowie\n'
#  'Kernzonen Kt. AG: ARE AG (2023); Buslinien und ÖV-Haltestellen: ZVV (2023)\n'
#  '\n'
#  'Hintergrund: swisstopo, Darstellung: AFM\n'
#  '\n'
#  '\n'
#  '-----\n'
#  '\n'
#  'Kanton Zürich, Volkswirtschaftsdirektion\n'
#  '\n'
#  'Amt für Mobilität\n'
#  '\n'
#  'AP Winterthur und Umgebung, 5. Generation\n'
#  'Teil 1: Bericht\n'
#  '\n'
#  '41/228\n'
#  '\n'
#  '4.1.2 Bevölkerung und Beschäftigte\n'
#  '\n'
#  "Aktuell wohnen im AP-Perimeter rund 206'000 Personen, während die Anzahl "
#  'Beschäftigte\n'
#  "sich auf 102'500 Personen beläuft.\n"
#  '\n'
#  '\n'
#  '![**Summary:**\n'
#  '\n'
#  'The image displays population trends in urban areas from 2001 to 2040, '
#  'showing increasing population growth over time.\n'
#  '\n'
#  '**Text Extraction:**\n'
#  '\n'
#  'Verhältnis EW/Besch.\n'
#  'Verhältnis EW/Besch. Kz. ZH](#)\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '**Abbildung 5** **Verhältnis der Bevölkerung zur Anzahl der Beschäftigten**\n'
#  '\n'
#  'Quellen: AFM 2023, Statistisches Amt Kt.ZH; Eigene Darstellung\n'
#  '\n'
#  'Bevölkerung\n'
#  '\n'
#  "Von den knapp 206'000 Einwohnerinnen und Einwohnern im AP-Perimeter lebten "
#  'im Jahr\n'
#  "2022 mehr als die Hälfte (ca. 118'600) in der Kernstadt Winterthur. "
#  'Insgesamt leben aktuell\n'
#  'drei Viertel der Bevölkerung im urbanen Raum (Stadt- und urbane '
#  'Wohnlandschaften gemäss ROK). Das Bevölkerungswachstum zwischen 2011 und '
#  '2022 liegt mit rund 13% knapp\n'
#  'unter dem kantonalen Wachstum von rund 14%. Der urbane und ländliche Raum '
#  'wuchsen\n'
#  '\n'
#  'jeweils beide gleich stark.\n'
#  '\n'
#  "Der Kanton prognostiziert für den AP-Perimeter ca. 241'000 Einwohnerinnen "
#  'und Einwohner\n'
#  "im Prognosehorizont 2040 und rund 259'000 im Jahr 2050. Bis 2040 bedeutet "
#  'dies einen\n'
#  "Zuwachs von gut 35'700 Einwohnerinnen und Einwohnern oder 17% gegenüber dem "
#  'Jahr\n'
#  "2022. Rund 140'000 Personen werden 2040 in der Kernstadt Winterthur leben "
#  "und ca. 22'000\n"
#  '\n'
#  'in Illnau-Effretikon. Zusammen mit den restlichen urbanen Gemeinden werden '
#  'mehr als drei\n'
#  '\n'
#  'Viertel der Bevölkerung 2040 im bereits heute dichten urbanen Raum leben.\n'
#  '\n'
#  '\n'
#  '-----\n'
#  '\n'
#  'Kanton Zürich, Volkswirtschaftsdirektion\n'
#  '\n'
#  'Amt für Mobilität\n'
#  '\n'
#  'AP Winterthur und Umgebung, 5. Generation\n'
#  'Teil 1: Bericht\n'
#  '\n'
#  '42/228\n'
#  '\n'
#  'Beschäftigte\n'
#  '\n'
#  "Die 2020 gezählten 102'500 Beschäftigten im AP-Perimeter verteilen sich zu "
#  '85% auf den\n'
#  'urbanen Raum und lediglich zu 15% auf den ländlichen Raum. Die Verteilung '
#  'der Beschäftigten innerhalb des AP-Perimeters blieb im Vergleich zu 2011 '
#  'gleich. Im Zeitraum zwischen\n'
#  '2011 und 2020 hat die Anzahl der Beschäftigten insgesamt um 11% zugenommen, '
#  'gegenüber einem Anstieg von 10% im Kanton Zürich.\n'
#  '\n'
#  "Den grössten Zuwachs verzeichneten mit rund 7'400 Beschäftigten die Stadt "
#  'Winterthur und\n'
#  'mit rund 700 Beschäftigten Lindau. Dieser grosse Zuwachs verdeutlicht die '
#  'überregionale\n'
#  'Bedeutung der Arbeitsstandorte Winterthur und Kemptthal. In den restlichen '
#  'Gemeinden des\n'
#  'AP-Perimeters war das Wachstum absolut betrachtet gering (< 500 Beschäftige) '
#  'und in den\n'
#  'Gemeinden Altikon, Brütten, Dägerlen, Elsau, Hagenbuch, Schlatt und '
#  'Weisslingen sogar\n'
#  'rückläufig. Das Wachstum der Beschäftigten im urbanen Raum war relativ '
#  'betrachtet leicht\n'
#  'höher als im ländlichen Raum, in absoluten Zahlen war das Wachstum im '
#  'urbanen Raum\n'
#  'deutlich stärker. Der geringere Beschäftigtenzuwachs gegenüber dem '
#  'Bevölkerungswachstum im ländlichen Raum führt zu stärkeren Pendlerströmen zu '
#  'den Arbeitsstätten in den Zentren. Aufgrund der geringen ÖV-Güteklasse in '
#  'diesen Gemeinden ist davon auszugehen,\n'
#  'dass die Pendlerwege vor allem mit dem MIV zurückgelegt werden.\n'
#  '\n'
#  'Die Beschäftigtenprognose des Kantons Zürich für den AP-Perimeter zeigt '
#  'einen Anstieg\n'
#  "von 102'500 auf rund 114'000 Beschäftigte im Jahr 2040. Dies entspricht "
#  'einem Wachstum\n'
#  'von rund 12%. Das Verhältnis von Einwohnerinnen und Einwohnern zu '
#  'Beschäftigten der\n'
#  'Region Winterthur und Umgebung liegt mit dem Faktor 1.95 über dem kantonalen '
#  'Mittel von\n'
#  '1.47. Ein gutes und ausreichendes Angebot von Beschäftigungsmöglichkeiten '
#  'ist Voraussetzung für eine starke Region. Unter der Annahme einer '
#  'Erwerbsquote von 0.5 reicht das Arbeitsplatzangebot in der Region aktuell '
#  'aus, obwohl sich über die Region verteilt grosse Unterschiede zeigen. So '
#  'beträgt das Verhältnis in der Stadt Winterthur beispielsweise 1.51 im\n'
#  'Jahr 2020. Da die prognostizierte relative Zunahme der Bevölkerung (17%) '
#  'höher liegt als\n'
#  'jene der Beschäftigten (12%), wird sich der Anteil von Beschäftigten an der '
#  'Bevölkerung der\n'
#  'Region Winterthur und Umgebung zu einem Verhältnis von 2.11 Einwohnerinnen '
#  'und Einwohnern je Beschäftigten im Jahr 2040 ändern. Damit hätte es künftig '
#  'leicht weniger Arbeitsplätze in der Region als Erwerbstätige, was zu '
#  'vermehrter Mobilität (weitere Arbeitswege zu\n'
#  'Arbeitsplätzen in angrenzenden Räumen) führen könnte.\n'
#  '\n'
#  '\n'
#  '![**Summary:**\n'
#  '\n'
#  'Die Bevölkerung, Verkehr, Maßnahmen, Raum, Arbeit, Arbeitsplätze, '
#  'Innenräume.\n'
#  '\n'
#  '**Extracted Text:**\n'
#  '\n'
#  'Die Bevölkerung, Verkehr, Maßnahmen, Raum, Arbeit, Arbeitsplätze, '
#  'Innenräume](#)\n'
#  '\n'
#  '-----\n'
#  '\n'
#  'Kanton Zürich, Volkswirtschaftsdirektion\n'
#  '\n'
#  'Amt für Mobilität\n'
#  '\n'
#  'AP Winterthur und Umgebung, 5. Generation\n'
#  'Teil 1: Bericht\n'
#  '\n'
#  '43/228\n'
#  '\n'
#  'EW / ÖV-Güteklasse – hoher Anteil gut erschlossen\n'
#  '\n'
#  '\n'
#  '![**Summary:**\n'
#  '\n'
#  'The image contains text related to the 2017, 2016, 2015, 2014, 2013, 2012, '
#  '2011, 2010, 2009, and 2008 years. The text also mentions various indicators, '
#  'including 45%, 20%, 10% and the word "Bewertung" (assessment). It includes '
#  'data from various municipalities, such as “Verkehrsmitteilen” (traffic '
#  'information) and mentions "Einwohnerrinnen und Einwohnern" (residents).\n'
#  '\n'
#  '**Extracted Text:**\n'
#  '\n'
#  '2017\n'
#  '2016\n'
#  '2015\n'
#  '2014\n'
#  '2013\n'
#  '2012\n'
#  '2011\n'
#  '2010\n'
#  '2009\n'
#  '2008\n'
#  'Einwohnerrinnen und Einwohnern\n'
#  'Verkehrsmitteilen\n'
#  'Bewertung\n'
#  '45%\n'
#  '20%\n'
#  '10%\n'
#  '](#)\n'
#  '\n'
#  '\n'
#  '![**Summary:**\n'
#  '\n'
#  'Three-fifty, fifty-one, one hundred\n'
#  '\n'
#  '**Text Extraction:**\n'
#  '\n'
#  'three-fifty\n'
#  'fifty-one\n'
#  'one hundred](#)\n'
#  '\n'
#  '![#3-50\n'
#  '#51-100\n'
#  '#>100\n'
#  '\n'
#  'Öberschdorf\n'
#  'Süglingen\n'
#  'Schlaitz\n'
#  'Weissenhorn\n'
#  'Möschingen\n'
#  'Gutenburg\n'
#  'Weikingen\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Stöckhartingen\n'
#  'Langenhard\n'
#  'Zell ZH\n'
#  'Züschenthal\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen\n'
#  'Böhlweiler\n'
#  'Rütingen](#)\n'
#  '\n'
#  '**Abbildung 6** **MOCA-Indikator 3 – Einwohnerinnen und Einwohner nach '
#  'ÖV-Güteklassen 2022**\n'
#  '\n'
#  'Anmerkungen: Dargestellt ist die Anzahl Einwohnerinnen und Einwohner im '
#  'Hektarraster\n'
#  'nach ÖV-GK gemäss der Definition des ARE.\n'
#  'Quellen: Bevölkerung: Statistisches Amt Kt. ZH (2022), ÖV-GK: ARE-CH (2022) '
#  '– OGD\n'
#  '«ÖV Güteklassen»\n'
#  '\n'
#  'Hintergrund: swisstopo, Darstellung: AFM\n'
#  '\n'
#  '\n'
#  '-----\n'
#  '\n'
#  'Kanton Zürich, Volkswirtschaftsdirektion\n'
#  '\n'
#  'Amt für Mobilität\n'
#  '\n'
#  'AP Winterthur und Umgebung, 5. Generation\n'
#  'Teil 1: Bericht\n'
#  '\n'
#  '44/228\n'
#  '\n'
#  'Beschäftigte / ÖV-Güteklasse – hoher Anteil gut erschlossen\n'
#  '\n'
#  '\n'
#  '![**Summary:**\n'
#  '\n'
#  'The image displays a document containing information about MOA-Indikatoren '
#  '(MOA indicators) related to the 2017 budget in Wuppertal, specifically '
#  'concerning the 2017 budget in Wuppertal. It highlights the urban areas and '
#  'relates to the 2017 budget.\n'
#  '\n'
#  '**Extracted Text:**\n'
#  '\n'
#  'Beitrachtung der MOA-Indikatoren, welche den 2017 fünf\n'
#  'Budgetstellen in Wuppertal, speziell der 2017\n'
#  'Budget in Wuppertal. Es zeigt die urbanen Gebiete und ist\n'
#  'mit dem Arbeitsplatz und OV-Erschliessung noch\n'
#  'zurückestellt.\n'
#  '\n'
#  '2017 fünf Budgetstellen in Wuppertal, speziell der\n'
#  '2017 Budget in Wuppertal. Es zeigt die urbanen Gebiete und ist\n'
#  'mit dem Arbeitsplatz und OV-Erschliessung noch\n'
#  'zurückestellt.](#)\n'
#  '\n'
#  '\n'
#  '![**Summary:**\n'
#  '\n'
#  'The image displays a colorful, geometric pattern consisting of squares and '
#  'circles in various shades of red, yellow, and blue.\n'
#  '\n'
#  '**Extracted Text:**\n'
#  '\n'
#  '3-50\n'
#  '51-200\n'
#  '>200](#)\n'
#  '\n'
#  '![**Summary:**\n'
#  '\n'
#  'Detailed map of a German region (likely Baden-Württemberg) showing a complex '
#  'patchwork of urban, rural, and forested areas. Numerous small villages and '
#  'towns are dispersed throughout the landscape, with significant areas of '
#  'dense built-up regions mixed with vast areas of greenery.\n'
#  '\n'
#  '**Extracted Text:**\n'
#  '\n'
#  'Winterthur\n'
#  '](#)\n'
#  '\n'
#  '**Abbildung 7** **MOCA-Indikator 4 – Beschäftigte nach ÖV-Güteklassen '
#  '2020**\n'
#  '\n'
#  'Anmerkungen: Dargestellt ist die Beschäftigtenzahl im Hektarraster nach '
#  'ÖV-GK gemäss\n'
#  'der Definition des ARE.\n'
#  'Datengrundlage: Beschäftigte: Statistisches Amt Kt. ZH (2020), '
#  'ÖV-Güteklassen: ARECH (2020) – OGD «ÖV Güteklassen»; Kt. AG: Berechnung '
#  'durch die Abteilung Verkehr\n'
#  '\n'
#  'Hintergrund: swisstopo, Darstellung: AFM\n'
#  '\n')

# %% [markdown]
# Apparently the parser interprets the coloured textboxes as image? However, the extraction is very poor! The summaries for the images as well, there is hardly any use / value to them.
